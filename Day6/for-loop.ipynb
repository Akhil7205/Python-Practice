# %%
s="tomorrow is weekend and non-veg special"
D=dict(enumerate(s.split()))
print(D)
# Out:
# {0: 'tomorrow', 1: 'is', 2: 'weekend', 3: 'and', 4: 'non-veg', 5: 'special'}

# %%
from ast import Dict
# 16.wap to create a dictionary words and its
# length pair
# s="tomorrow is weekend and non-veg special"
# o/p:-->{'tomorrow': 8, 'is': 2, 'weekend': 7,
# 'and': 3, 'non-veg': 7, 'special': 7}
s="tomorrow is weekend and non-veg special"
d={}
for i,j in enumerate(s.split()):
  d[j]=len(j)
print(d)
# Out:
# {'tomorrow': 8, 'is': 2, 'weekend': 7, 'and': 3, 'non-veg': 7, 'special': 7}

# %%
# 17.wap to create a dictionary characters and its
# corresponding upper case characters
# s="sunday"
# o/p:-->{'s': 'S', 'u': 'U', 'n': 'N', 'd': 'D',
# 'a': 'A', 'y': 'Y'}
s="sunday"
d={}
for i in s:
  d[i]=i.upper()
print(d)
# Out:
# {'s': 'S', 'u': 'U', 'n': 'N', 'd': 'D', 'a': 'A', 'y': 'Y'}

# %%
# 18.wap to create a dictionary Ascii and character
# pair
# l=[89,51,111,77,108,120]
# o/p:-->{89: 'Y', 51: '3', 111: 'o', 77: 'M', 108:
# 'l', 120: 'x'}
l=[89,51,111,77,108,120]
d={ch:chr(ch) for ch in l}
print(d)
# Out:
# {89: 'Y', 51: '3', 111: 'o', 77: 'M', 108: 'l', 120: 'x'}

# %%
# 19.wap to create a list of characters and its
# Ascii value pair
# s="sunday"
# o/p:-->[('s', 115), ('u', 117), ('n', 110), ('d',
# 100), ('a', 97), ('y', 121)]
s="sunday"
d={ch:ord(ch) for ch in s}
print(d)
# Out:
# {'s': 115, 'u': 117, 'n': 110, 'd': 100, 'a': 97, 'y': 121}

# %%
# 20.WAp to perform clear() in list without using
# inbuilt method
l=[1,2,3,4,4]
for i in range(len(l)):
  l.pop()
print(l)
# Out:
# []

# %%
# 21.wap to create a dictionary with words and its
# length pair and ends with vowel
s="Today is Tuesday and attending python session "
# d={ch:ch.len() for ch in enumerate(s.split())}
# print(d)
d={}
v='aeiou'
for ch in s.split():
  if ch[-1] in v:
    d[ch]=[len(ch)]
print(d)
# Out:
# {}

# %%
# 22.wap to create a dictionary with letter and its
# words starting with that letter pair
# s="hi hello good morning welcome to python
# session"
# o/p:-->{'h': ['hi', 'hello'], 'g': ['good'], 'm':
# ['morning'], 'w': ['welcome'], 't': ['to'], 'p':
# ['python'], 's': ['session']}
s="hi hello good morning welcome to  python"
d={}
for ch in s.split():
  key=ch[0]
  if key not in d:
    d[key]=[ch]
  else:
    d[key].append(ch)
print(d)
# Out:
# {'h': ['hi', 'hello'], 'g': ['good'], 'm': ['morning'], 'w': ['welcome'], 't': ['to'], 'p': ['python']}

# %%
  # 23.wap to create a dictionary of characters and
# its indices pair
# s="hello python"
# o/p:-->{"h":[0,9],"e":1..........}
s="hello python"
d={}
for i,j in enumerate(s):
    if j not in d:
      d[j]=[i]
    else:
      d[j].append(i)
print(d)
# Out:
# {'h': [0, 9], 'e': [1], 'l': [2, 3], 'o': [4, 10], ' ': [5], 'p': [6], 'y': [7], 't': [8], 'n': [11]}

# %%
# 24.wap to create a dictionary word and reverse
# word pair
# s="tomorrow is weekend and non-veg special"
# o/p:-->{'tomorrow': 'worromot', 'is': 'si',
# 'weekend': 'dnekeew', 'and': 'dna', 'non-veg':
# 'gev-non', 'special': 'laiceps'}
s="tomorrow is weekend and non-veg special"
d={ch:ch[::-1] for ch in s.split()}
print(d)
# Out:
# {'tomorrow': 'worromot', 'is': 'si', 'weekend': 'dnekeew', 'and': 'dna', 'non-veg': 'gev-non', 'special': 'laiceps'}

# %%
# 25.Reverse a list without using any built-in
# functions and slicing.
# l = [1, 2, 3, 4]
l = [1, 2, 3, 4]
rev=[]
le=len(l)-1
for i  in range(len(l)):
  a=le-i
  rev.append(l[a])
print(rev)
# Out:
# [4, 3, 2, 1]

# %%
l = [1, 2, 3, 4]
rev = []

i = len(l) - 1
while i >= 0:
    rev.append(l[i])
    i -= 1

print(rev)
# Out:
# [4, 3, 2, 1]
