# %%
pdf=open('sample-report.pdf','rb')

# %%
# pdf.readlines()
for i in pdf:
  print(i.rstrip('\n'))

# %%
csv=open('/content/sample_data/california_housing_train.csv','r')

# %%
# csv.readlines()
for i in csv:
  print(i.rstrip('\n'))

# %%
a=9
b=0
# c=a/b
try:
   print(a/b)
except:
      print('not possoible to div')
# print('a')
# Out:
# not possoible to div

# %%
try:
  print(a/7)
  print(a/c)
except:
  print(a/8)
# Out:
# 1.2857142857142858
# 1.125

# %%
l=[2,2,3]
try:
  print(sort(l))
except:
  print('handle exception')
# Out:
# handle exception

# %%
l = [10, 20]
try:
  print(i.upper())
except NameError:
#AttributeError
  print("handling name error")
except ZeroDivisionError:
  print("handling division error")
except AttributeError:
  print("handling AttributeError" )
# Out:
# handling name error

# %%
a = 10
b = 0
try:
  print(a/b)
except BaseException as msg:
    print("exception handling")
    print(msg)
# Out:
# exception handling
# division by zero

# %%
try:
  print(a/c)
except BaseException as err:
  print(err)
# Out:
# name 'c' is not defined

# %%
b = 2
try:
  print(10/1)
  try:
      print(c)
  except NameError:
      print("handling name error")
except BaseException as err:
  print(err)
# Out:
# 10.0
# handling name error

# %%
class NegativeNumberError(Exception):
    pass

def check(no):
    if no < 0:
        raise NegativeNumberError("Negative number not allowed")
    else:
        print("Number is positive")

check(3)
check(-2)
# Out:
# Number is positive
# ---------------------------------------------------------------------------
# NegativeNumberError                       Traceback (most recent call last)
# /tmp/ipython-input-3778838864.py in <cell line: 0>()
#       9
#      10 check(3)
# ---> 11 check(-2)
#
# /tmp/ipython-input-3778838864.py in check(no)
#       4 def check(no):
#       5     if no < 0:
# ----> 6         raise NegativeNumberError("Negative number not allowed")
#       7     else:
#       8         print("Number is positive")
#
# NegativeNumberError: Negative number not allowed

# %%
class NegativeNumber(BaseException):
  ...
def check(no):
    if no < 0:
      raise NegativeNumber
    else:
        print("no is positive")

check(3)
check(-2)
# Out:
# no is positive
# ---------------------------------------------------------------------------
# NegativeNumber                            Traceback (most recent call last)
# /tmp/ipython-input-2336716790.py in <cell line: 0>()
#       8
#       9 check(3)
# ---> 10 check(-2)
#
# /tmp/ipython-input-2336716790.py in check(no)
#       3 def check(no):
#       4     if no < 0:
# ----> 5       raise NegativeNumber
#       6     else:
#       7         print("no is positive")
#
# NegativeNumber:

# %%
class Passwordlengthlessthan6(BaseException):
  ...
class EnterValidPassword(BaseException):
  ...
def password(pwd):
  if len(pwd) > 6:
    if pwd.isalnum():
      print("valid password")
    else:
      raise EnterValidPassword
  else:
    raise Passwordlengthlessthan6
password("abc2456")
# Out:
# valid password

# %%
class pwd(BaseException):
  pass
class vpwd(BaseException):
  pass
def password(pwd):
  if len(pwd)>6:
    if pwd is alnum():
      print('')
    else:
        raise vpwd

    print('valid pwd')
  else:
    raise vpwd
