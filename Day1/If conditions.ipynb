# %%
# Q1 wap to check the number is oddor even (take user input)
num=int(input('enter no:'))
if num%2==0:
  print('it is even no')
else:
  print('it is odd no')
# Out:
# enter no:5
# it is odd no

# %%
# Q2 .wap to check if the student has scored 70%  print "good luck "(take user input)
marks=int(input('Enter marks in %:'))
if marks >70:
  print('good luck')
else:
  print('marks should be greater than 70')
# Out:
# Enter marks in %:71
# good luck

# %%
# Q4.wap to check which number is greater using
# if condition
a=98
b=67
if a>b:
  print('a is greater than b')
else:
  print('b is greater than a')
# Out:
# a is greater than b

# %%
# 5.wap to check if the given string has even length of character
s="hey guys you all are Osam"

if len(s)%2==0:
  print('s length is even')
else:
  print('s length is no even')
# Out:
# s length is no even

# %%
# 6.wap to check if the given number is divisible by 5 (take user input)
no=int(input('Enter no to check it is div by 5:'))
if no%5==0:
  print('no is div by 5')
else:
  print('no is not div by 5')
# Out:
# Enter no to check it is div by 5:35
# no is div by 5

# %%
# 7.wap to check if the given programming is present in the list
p=["java","python","c","c++","RUBy","golang"]
write=input('Enter the programming lang:')
if write in p:
  print('lang is present in list')
else:
  print('lang is present in list')
# Out:
# Enter the programming lang:py
# lang is present in list

# %%
# 8.wap to check eligible to vote take user input as a age
age=int(input('Enter your age:'))
if age>18:
  print('you are eligible to vote')
else:
  print('you are not eligible to vote')
# Out:
# Enter your age:34
# you are eligible to vote

# %%
# 9.wap to check if the given number is positive take user input
no=int(input('Enter noto check +|- :'))
if no>=0:
  print('no is +ve')
else:
  print('no is -ve')
# Out:
# Enter noto check +|- :-2
# no is -ve

# %%
# 10.wap to check if the given string is palindrome (take user input)
str=(input('Enter the str to check palindrome:'))
if str==str[::-1]:
  print('str is palindrome')
else:
  print('str is not palindrome')
# Out:
# Enter the str to check palindrome:sts
# str is palindrome

# %%
# 11.wap to check if the first letter in the given string is consonant
s="Lahari is a good student"
c=['a','e','i','o','u']
if s.strip()[0].lower() not in c:
  print('it is consonant')
else:
  print('its not a consonant')
# Out:
# it is consonant

# %%
# 12.wap to check the given string is uppercase or not (take user input)

string=(input('Enter the str is uppercase:'))
if string.upper()==string:
  print('str is uppercase')
else:
  print('str is not uppercase')
# Out:
# Enter the str is uppercase:AD
# str is uppercase

# %%
# 13.wap to check the given value is string (take user input)
string=(input('Enter the str:'))
if string.isalpha():
  print('written is string:')
else:
  print('written type is not string')
# Out:
# Enter the str:sadf3
# written type is not string

# %%
# 14.wap to display "Python Coding" if the number is greater than 1 and less than 5 (take user input)
no=int(input('Enter the no:'))
if no>1 and no<5:
  print('python code')
else:
  print('enter no less than 5')
# Out:
# Enter the no:3
# python code

# %%
# 15.wap to check whether given number is negative and print "its negative guys"
no=int(input('Enter the no:'))
if no<0:
  print('-ve guys')
else:
  print('enter no less than 0')
# Out:
# Enter the no:-2
# -ve guys

# %%
# 16.wap to check whether given input is divisible by 2 and 6 if condition is True ,convert the given number to complexnumber.(take user input)
no=int(input('Enter the no:'))
if no%2==0 and no%6==0:
  print(complex(no))
else:
  print('no is not div by 2 and 6')
# Out:
# Enter the no:12
# (12+0j)

# %%
# 17.wap to check whether the given number is even or not,if even store the value inside  the list (take user input)
num=int(input('enter no:'))
l=[]
if num%2==0:
  l.append(num)
  print('it is even no')
else:
  print('it is odd no')
print(l)
# Out:
# enter no:4
# it is even no
# [4]

# %%
# 19.wap to check whether a given value is divisible by 5 and 7,if the value is divisible then display the square of the values (take user input)
no=int(input('Enter the no:'))
if no%5==0 and no%7==0:
  print(no*no)
else:
  print('no is not div by 5 and 7')
# Out:
# Enter the no:35
# 1225

# %%
# 20.wap to check whether a given value is present in between 45 and 200 and the number should be divisible by 4 and 5 ,if
# satisfied,display the ascii characters (take user input)
no=int(input('Enter the no:'))
if no>45 and no<200 and no%5==0 and no%4==0:
  print('Ascii char is :',chr(no))
else:
  print('condition not statisfied')
# Out:
# Enter the no:80
# Ascii char is : P

# %%
# 21.wap to checking if a string contains a substring
string = input("Enter string: ")
sub_string = input("Enter substring: ")

if sub_string.lower() in string.lower():
    print("Substring is present")
else:
    print("Substring is not present")
# Out:
# Enter string: As
# Enter substring: aS
# Substring is present

# %%
# 22.wap to check whether a character is in the alphabet or not,if it is alphabet,store the value inside a dict(key as a character and value as a ascii value)
string=input('enter single char:')
a={}
if string.isalpha() and len(string)==1:
 ascii= a[string]=ord(string)
 print(a)
else:
  print('condition not matched')
# Out:
# enter single char:zv
# condition not matched

# %%
# 23.wap to check whether a character is in uppercase or not,if uppercase,convert to
#  lowercase and store the value inside the dictionary (character as key and ascii as value) take user input
string = input("Enter string: ")
d={}
if string.isupper() :
    lower=string.lower()
    d[lower]=ord(lower)
    print("string",d)
else:

    print("Substring is not present")
# Out:
# Enter string: S
# string {'s': 115}

# %%
f={}
a='D'
f['af']='sd'
print(f)
# Out:
# {'af': 'sd'}
